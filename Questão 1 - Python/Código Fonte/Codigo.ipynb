# %%
import pandas as pd
house = pd.read_csv('house_infos.csv')
print(house)
# Out:
#       LotFrontage  LotArea Street  OverallQual  YearBuilt BsmtQual  \
# 0            65.0     8450   Pave            7       2003       Gd
# 1            80.0     9600   Pave            6       1976       Gd
# 2            68.0    11250   Pave            7       2001       Gd
# 3            60.0     9550   Pave            7       1915       TA
# 4            84.0    14260   Pave            8       2000       Gd
# 5            85.0    14115   Pave            5       1993       Gd
# 6            75.0    10084   Pave            8       2004       Ex
# 7             NaN    10382   Pave            7       1973       Gd
# 8            51.0     6120   Pave            7       1931       TA
# 9            50.0     7420   Pave            5       1939       TA
# 10           70.0    11200   Pave            5       1965       TA
# 11           85.0    11924   Pave            9       2005       Ex
# 12            NaN    12968   Pave            5       1962       TA
# ...
